# %%
import requests
import re
from bs4 import BeautifulSoup

# %%
url = 'https://www.coursera.org/'
response = requests.get(url)
html_content = response.text

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %%
email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
emails = re.findall(email_pattern, html_content)
print(emails)
# Out:
# ['632c598283934f76a6a49e66102577da@o75955.ingest.sentry.io']

# %%
url_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
urls = re.findall(url_pattern, html_content)
print(urls)
# Out:
# ['http://ogp.me/ns/fb', 'http://schema.org', 'https://d3njjcbhbojbot.cloudfront.net', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-57x57.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-60x60.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-72x72.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-76x76.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-114x114.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-120x120.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-144x144.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-152x152.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-180x180.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/favicon-v2-194x194.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/android-chrome-v2-192x192.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/favicon-v2-96x96.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/favicon-v2-16x16.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/favicon-v2-32x32.png', 'https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/mstile-v2-144x144.png', 'https://d3njjcbhbojbot.cloudfront.net/web/type/source-sans-pro-v14-latin/source-sans-pro-v14-latin-regular.woff2', 'https://d3njjcbhbojbot.cloudfront.net/web/type/source-sans-pro-v14-latin/source-sans-pro-v14-latin-600.woff2', 'https://d3njjcbhbojbot.cloudfront.net/web/type/source-sans-pro-v14-latin/source-sans-pro-v14-latin-700.woff2', 'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.eot', 'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.eot?', 'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.woff', 'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.ttf', 'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.svg', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot?', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff2', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.ttf', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.svg', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.eot', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.eot?', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-regular.woff2', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-regular.woff', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.ttf', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.svg', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Semibold.eot', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Semibold.eot?', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-600.woff2', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-600.woff', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Semibold.ttf', 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Semibold.svg', "https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Bold.eot');", 'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Bold.eot?', "https://d3njjcb ...
